# %%
import requests
import nba_api
import pandas as pl
import io

# %%
from nba_api.stats.endpoints import *

# %%
player2 = commonallplayers.CommonAllPlayers()
player2_dict = player2.get_dict()

# %%
player2_resultSets = player2_dict['resultSets']
player2_dict_resultSets = player2_resultSets[0]
player2_headers_resultSets = player2_dict_resultSets['headers']
player2_rowSet_resultSets = player2_dict_resultSets['rowSet']

# %%
lf_player2 = pl.DataFrame(player2_rowSet_resultSets, columns = player2_headers_resultSets)

# %%
display(lf_player2.filter(pl.col('DISPLAY_FIRST_LAST').str.contains('Jokic')))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 display(lf_player2.filter(pl.col('DISPLAY_FIRST_LAST').str.contains('Jokic')))
#
# File c:\Users\tomas\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:5637, in NDFrame.filter(self, items, like, regex, axis)
#    5633         labels = self._get_axis(axis)
#    5634
#    5635         if items is not None:
#    5636             name = self._get_axis_name(axis)
# -> 5637             items = Index(items).intersection(labels)
#    5638             if len(items) == 0:
#    5639                 # Keep the dtype of labels when we are empty
#    5640                 items = items.astype(labels.dtype)
#
# File c:\Users\tomas\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:496, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
# ...

# %%
player = playerindex.PlayerIndex()
player_dict = player.get_dict()

# %%
player_resultSets = player_dict['resultSets']
player_dict_resultSets = player_resultSets[0]
player_headers_resultSets = player_dict_resultSets['headers']
player_rowSet_resultSets = player_dict_resultSets['rowSet']

# %%
lf_player = pl.DataFrame(player_rowSet_resultSets, columns = player_headers_resultSets)

# %%
display(lf_player)
# Out:
#      PERSON_ID PLAYER_LAST_NAME PLAYER_FIRST_NAME       PLAYER_SLUG  \
# 0      1630173          Achiuwa          Precious  precious-achiuwa
# 1       203500            Adams            Steven      steven-adams
# 2      1628389          Adebayo               Bam       bam-adebayo
# 3      1630534           Agbaji             Ochai      ochai-agbaji
# 4      1630583           Aldama             Santi      santi-aldama
# ..         ...              ...               ...               ...
# 577    1642959       Youngblood             Chris  chris-youngblood
# 578    1630209        Yurtseven              Omer    omer-yurtseven
# 579    1642911         Zikarsky             Rocco    rocco-zikarsky
# 580    1627826            Zubac             Ivica       ivica-zubac
# 581    1641783         da Silva           Tristan  tristan-da-silva
#
#         TEAM_ID     TEAM_SLUG  IS_DEFUNCT   TEAM_CITY      TEAM_NAME  \
# 0    1610612758         kings           0  Sacramento          Kings
# ...

# %%
display(lf_player.filter(pl.col('PLAYER_FIRST_NAME') == 'Lebron'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 display(lf_player.filter(pl.col('PLAYER_FIRST_NAME') == 'Lebron'))
#
# File c:\Users\tomas\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:5637, in NDFrame.filter(self, items, like, regex, axis)
#    5633         labels = self._get_axis(axis)
#    5634
#    5635         if items is not None:
#    5636             name = self._get_axis_name(axis)
# -> 5637             items = Index(items).intersection(labels)
#    5638             if len(items) == 0:
#    5639                 # Keep the dtype of labels when we are empty
#    5640                 items = items.astype(labels.dtype)
#
# File c:\Users\tomas\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:496, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
# ...

# %%
player_carrer = playercareerstats.PlayerCareerStats(player_id='203999')
player_carrer_dict = player_carrer.get_dict()

# %%
resultSets = player_carrer_dict['resultSets']
dict_reslultSets = resultSets[0]
headers_resultSets = dict_reslultSets['headers']
rowSet_resultSets = dict_reslultSets['rowSet']

# %%
lf = pl.DataFrame(rowSet_resultSets, columns = headers_resultSets)

# %%
display(lf)
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      203999   2015-16        00  1610612743               DEN        21.0
# 1      203999   2016-17        00  1610612743               DEN        22.0
# 2      203999   2017-18        00  1610612743               DEN        23.0
# 3      203999   2018-19        00  1610612743               DEN        24.0
# 4      203999   2019-20        00  1610612743               DEN        25.0
# 5      203999   2020-21        00  1610612743               DEN        26.0
# 6      203999   2021-22        00  1610612743               DEN        27.0
# 7      203999   2022-23        00  1610612743               DEN        28.0
# 8      203999   2023-24        00  1610612743               DEN        29.0
# 9      203999   2024-25        00  1610612743               DEN        30.0
# 10     203999   2025-26        00  1610612743               DEN        31.0
#
# ...
