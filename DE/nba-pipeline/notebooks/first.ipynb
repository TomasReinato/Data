# %%
import polars as pl

# %%
nba-pipeline/
├── src/
│   ├── __init__.py
│   ├── extract.py
│   ├── transform.py
│   └── config.py
├── data/
│   ├── bronze/
│   ├── silver/
│   └── gold/
├── notebooks/
│   └── analysis.ipynb
├── main.py
├── requirements.txt
├── .gitignore
└── README.md
